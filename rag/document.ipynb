# %% [markdown]
# ### CSV Loader Example

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

# %%
loader = CSVLoader(file_path="../data/sales.csv", source_column="ProductID")
sales_document = loader.load()
sales_document
# Out:
# [Document(metadata={'source': '102', 'row': 0}, page_content='SalesID: 1\nDate: 2023-01-01\nCustomerID: 4\nProductID: 102\nQuantity: 4\nPrice: 300\nRevenue: 1200'),
#  Document(metadata={'source': '102', 'row': 1}, page_content='SalesID: 2\nDate: 2023-01-08\nCustomerID: 5\nProductID: 102\nQuantity: 3\nPrice: 300\nRevenue: 900'),
#  Document(metadata={'source': '102', 'row': 2}, page_content='SalesID: 10\nDate: 2023-03-05\nCustomerID: 5\nProductID: 102\nQuantity: 1\nPrice: 300\nRevenue: 300'),
#  Document(metadata={'source': '102', 'row': 3}, page_content='SalesID: 16\nDate: 2023-04-16\nCustomerID: 2\nProductID: 102\nQuantity: 4\nPrice: 300\nRevenue: 1200'),
#  Document(metadata={'source': '102', 'row': 4}, page_content='SalesID: 17\nDate: 2023-04-23\nCustomerID: 4\nProductID: 102\nQuantity: 2\nPrice: 300\nRevenue: 600'),
# ...

# %%
sales_document[0].type
# Out:
# 'Document'
